# %%
# %pip install gensim
# Out:
# Note: you may need to restart the kernel to use updated packages.Collecting gensim
# ...
#    ---------------------------------------- 0.0/24.0 MB ? eta -:--:--
#    -- ------------------------------------- 1.3/24.0 MB 6.1 MB/s eta 0:00:04
#    --- ------------------------------------ 2.4/24.0 MB 6.4 MB/s eta 0:00:04
#    ---- ----------------------------------- 2.9/24.0 MB 4.9 MB/s eta 0:00:05
#    ----- ---------------------------------- 3.1/24.0 MB 4.3 MB/s eta 0:00:05
#    ----- ---------------------------------- 3.4/24.0 MB 3.1 MB/s eta 0:00:07
#    ----- ---------------------------------- 3.4/24.0 MB 3.1 MB/s eta 0:00:07
#    ----- ---------------------------------- 3.4/24.0 MB 3.1 MB/s eta 0:00:07
#    ------ --------------------------------- 3.7/24.0 MB 2.2 MB/s eta 0:00:10
#    ------ --------------------------------- 3.9/24.0 MB 2.0 MB/s eta 0:00:11
#    ------ --------------------------------- 3.9/24.0 MB 2.0 MB/s eta 0:00:11
# ...
